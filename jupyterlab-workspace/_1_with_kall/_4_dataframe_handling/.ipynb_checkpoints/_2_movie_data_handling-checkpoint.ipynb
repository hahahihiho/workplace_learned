# %% [markdown]
# ## 영화 평점 데이터
# 1. NA처리
# 2. 영화별 성별 평점 평균산출, 성별별 상하위 10개 목록, 도식화
# 3. 영화 평점정보가 300건 이상 있는영화 중, 여성에게 인기가 높은 10개
# 4. 남여간 호불호 가장큰 영화
# 5. 호불호가 큰 영화

# %%
import pandas as pd
import numpy as np

# %%
pd.options.display.max_rows=10

unames = ['user_id','gender','age','occupation','zip']
df_users = pd.read_csv('C:/data/kallisma1/movielens/users.dat',sep = '::',header=None,names=unames)
mnames = ['movie_id','title','genres']
df_movies = pd.read_csv('C:/data/kallisma1/movielens/movies.dat',sep='::',header=None,names=mnames)
rnames = ['user_id','movie_id','rating','timestamp']
df_ratings = pd.read_csv('C:/data/kallisma1/movielens/ratings.dat',sep='::',header=None,names=rnames)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   after removing the cwd from sys.path.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.

# %%
df_users.head()
# Out:
#    user_id gender  age  occupation    zip
# 0        1      F    1          10  48067
# 1        2      M   56          16  70072
# 2        3      M   25          15  55117
# 3        4      M   45           7  02460
# 4        5      M   25          20  55455

# %%
df_movies.head()
# Out:
#    movie_id                               title                        genres
# 0         1                    Toy Story (1995)   Animation|Children's|Comedy
# 1         2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2         3             Grumpier Old Men (1995)                Comedy|Romance
# 3         4            Waiting to Exhale (1995)                  Comedy|Drama
# 4         5  Father of the Bride Part II (1995)                        Comedy

# %%
df_ratings.head()
len(df_ratings)
# Out:
# 1000209

# %%
df_users.dtypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000209 entries, 0 to 1000208
# Data columns (total 8 columns):
# rating        1000209 non-null int64
# timestamp     1000209 non-null int64
# gender        1000209 non-null object
# age           1000209 non-null int64
# occupation    1000209 non-null int64
# zip           1000209 non-null object
# title         1000209 non-null object
# genres        1000209 non-null object
# dtypes: int64(4), object(4)
# memory usage: 68.7+ MB

# %%
np.unique(df_ratings.isna())
np.unique(df_movies.isna())
np.unique(df_users.isna())
# Out:
# array([False])

# %%
df_ratings.merge(df_movies).merge(df_users)
# Out:
#          user_id  movie_id  rating  timestamp  \
# 0              1      1193       5  978300760
# 1              1       661       3  978302109
# 2              1       914       3  978301968
# 3              1      3408       4  978300275
# 4              1      2355       5  978824291
# ...          ...       ...     ...        ...
# 1000204     4211      3791       2  965319075
# 1000205     4211      3806       3  965319138
# 1000206     4211      3840       4  965319197
# 1000207     4211      3766       2  965319138
# 1000208     4211      3834       2  965318885
#
#                                           title                        genres  \
# 0        One Flew Over the Cuckoo's Nest (1975)                         Drama
# 1              James and the Giant Peach (1996)  Animation|Children's|Musical
# 2                           My Fair Lady (1964)               Musical|Romance
# 3                        Erin Brockovich (2000)                         Drama
# ...

# %%
df = df_ratings.merge(df_users).merge(df_movies)

# %%
df.drop(['user_id','movie_id'],inplace=True,axis='columns')
df_gbym = df.groupby(['title','gender'])
df_gbym.first()
# df_gbym.get_group('$1,000,000 Duck (1971)')
# Out:
#                                                    rating   timestamp  age  \
# title                                      gender
# $1,000,000 Duck (1971)                     F            5   976215651   35
#                                            M            2   976867230   45
# 'Night Mother (1986)                       F            3   976574062   35
#                                            M            5   977883710   18
# 'Til There Was You (1997)                  F            2   978045250   18
# ...                                                   ...         ...  ...
# Zero Kelvin (Kj�rlighetens kj�tere) (1995) M            3  1031532546   35
# Zeus and Roxanne (1997)                    F            2   974760923   25
#                                            M            3   975278974   18
# eXistenZ (1999)                            F            3   988496419   45
#                                            M            2   978229391   25
#
# ...

# %%
df_temp = df_gbym['rating'].mean()
df_temp.unstack()
# Out:
# gender                                             F         M
# title
# $1,000,000 Duck (1971)                      3.375000  2.761905
# 'Night Mother (1986)                        3.388889  3.352941
# 'Til There Was You (1997)                   2.675676  2.733333
# 'burbs, The (1989)                          2.793478  2.962085
# ...And Justice for All (1979)               3.828571  3.689024
# ...                                              ...       ...
# Zed & Two Noughts, A (1985)                 3.500000  3.380952
# Zero Effect (1998)                          3.864407  3.723140
# Zero Kelvin (Kj�rlighetens kj�tere) (1995)       NaN  3.500000
# Zeus and Roxanne (1997)                     2.777778  2.357143
# eXistenZ (1999)                             3.098592  3.289086
#
# [3706 rows x 2 columns]

# %%
df_temp.plot.bar()

# %% [markdown]
# # na 처리
# dropna(how=any)

# %%
df_df_temp[0:20]
# Out:
# title                                                       gender
# Blood Spattered Bride, The (La Novia Ensangrentada) (1972)  M         1.0
# Cheetah (1989)                                              F         1.0
# Low Life, The (1994)                                        M         1.0
# Babyfever (1994)                                            M         1.0
# Loves of Carmen, The (1948)                                 F         1.0
#                                                                      ...
# Kronos (1957)                                               F         1.0
# Truce, The (1996)                                           F         1.0
# Stalingrad (1993)                                           F         1.0
# Lotto Land (1995)                                           M         1.0
# Carnosaur 3: Primal Species (1996)                          F         1.0
# Name: rating, Length: 20, dtype: float64

# %%
pivot_title_gender = df.pivot_table('rating',index='title',columns='gender',aggfunc='mean')

# %%
pivot_title_gender.sort_values('F')[0:10]
pivot_title_gender.sort_values('F',ascending=False)[0:10]
pivot_title_gender.sort_values('M')[0:10]
pivot_title_gender.sort_values('M',ascending=False)[0:10]
# Out:
# gender                                            F    M
# title
# Schlafes Bruder (Brother of Sleep) (1995)       NaN  5.0
# Small Wonders (1996)                       3.333333  5.0
# Gate of Heavenly Peace, The (1995)         5.000000  5.0
# Baby, The (1973)                                NaN  5.0
# Ulysses (Ulisse) (1954)                         NaN  5.0
# Dangerous Game (1993)                      4.000000  5.0
# Angela (1995)                              3.000000  5.0
# Bells, The (1926)                          4.000000  5.0
# Smashing Time (1967)                            NaN  5.0
# Follow the Bitch (1998)                         NaN  5.0

# %%
df
# Out:
#          rating  timestamp gender  age  occupation    zip  \
# 0             5  978300760      F    1          10  48067
# 1             5  978298413      M   56          16  70072
# 2             4  978220179      M   25          12  32793
# 3             4  978199279      M   25           7  22903
# 4             5  978158471      M   50           1  95350
# ...         ...        ...    ...  ...         ...    ...
# 1000204       5  958846401      M   18          17  47901
# 1000205       3  976029116      M   35          14  30030
# 1000206       1  958153068      M   18          17  92886
# 1000207       5  957756608      F   18          20  55410
# 1000208       4  957273353      M   25           1  35401
#
#                                                title                genres
# 0             One Flew Over the Cuckoo's Nest (1975)                 Drama
# 1             One Flew Over the Cuckoo's Nest (1975)                 Drama
# ...

# %%
df.groupby('title').count()
# Out:
#                                             rating  timestamp  gender  age  \
# title
# $1,000,000 Duck (1971)                          37         37      37   37
# 'Night Mother (1986)                            70         70      70   70
# 'Til There Was You (1997)                       52         52      52   52
# 'burbs, The (1989)                             303        303     303  303
# ...And Justice for All (1979)                  199        199     199  199
# ...                                            ...        ...     ...  ...
# Zed & Two Noughts, A (1985)                     29         29      29   29
# Zero Effect (1998)                             301        301     301  301
# Zero Kelvin (Kj�rlighetens kj�tere) (1995)       2          2       2    2
# Zeus and Roxanne (1997)                         23         23      23   23
# eXistenZ (1999)                                410        410     410  410
#
# ...

# %%
df.groupbyby('title').size()
# Out:
# title
# $1,000,000 Duck (1971)                         37
# 'Night Mother (1986)                           70
# 'Til There Was You (1997)                      52
# 'burbs, The (1989)                            303
# ...And Justice for All (1979)                 199
#                                              ...
# Zed & Two Noughts, A (1985)                    29
# Zero Effect (1998)                            301
# Zero Kelvin (Kj�rlighetens kj�tere) (1995)      2
# Zeus and Roxanne (1997)                        23
# eXistenZ (1999)                               410
# Length: 3706, dtype: int64

# %%
mlist_over300 = df.groupby('title').size().index[(df.groupby('title').size()>=300)]

# %%
df[df['title'].isin(mlist_over300)]
df_over300_pivot = df_temp.unstack()[df_temp.unstack().index.isin(mlist_over300)]
a=df_over300_pivot['F'].sort_values()[:10]
df_over300_pivot['F'].sort_values(ascending=False)[:10]
df_over300_pivot['M'].sort_values()[:10]
df_over300_pivot['M'].sort_values(ascending=False)[:10]
# Out:
# title
# Godfather, The (1972)                                                  4.583333
# Seven Samurai (The Magnificent Seven) (Shichinin no samurai) (1954)    4.576628
# Shawshank Redemption, The (1994)                                       4.560625
# Raiders of the Lost Ark (1981)                                         4.520597
# Usual Suspects, The (1995)                                             4.518248
# Star Wars: Episode IV - A New Hope (1977)                              4.495307
# Schindler's List (1993)                                                4.491415
# Wrong Trousers, The (1993)                                             4.478261
# Close Shave, A (1995)                                                  4.473795
# Rear Window (1954)                                                     4.472991
# Name: M, dtype: float64

# %%
a.plot.bar()
